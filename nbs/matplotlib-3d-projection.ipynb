# %% [markdown]
# ## Jupyter Notebook test
#
# Uploaded 10/19/2019

# %%
# !python -V

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
# Out:
# Python 3.7.3

# %%
from mpl_toolkits import mplot3d
fig = plt.figure()
ax = plt.axes(projection='3d')

# %%
ax = plt.axes(projection='3d')

# Data 3d
zline = np.linspace(0, 15, 1000)  # linearly spaced, 0 to 15, 1000 points)
xline = np.sin(zline)  # sine of zline
yline = np.cos(zline)  # cosine of zline 
ax.plot3D(xline, yline, zline,  'gray')

# Data for scattered points along the line-spiral

zdata = 15 * np.random.random(100)  # 100 random points along z-axis.
xdata = np.sin(zdata) + 0.1 * np.random.randn(100)  # random perterbation on x-axis.
ydata = np.cos(zdata) + 0.1 * np.random.randn(100)  # random perterbation on y-axis.
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='Greens');
